# %%
import matplotlib.pyplot as plt
btc_Dolar = [0.06, 6.05, 8.46, 189.54, 526.02, 272.36, 567.27, 4001, 7559, 7367, 27894]
btc_Tl = [0.09, 10.71, 14.81, 405.62, 1225, 795.30, 1997, 14085, 36280, 41987, 204700]
yıllar = [2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]

plt.plot(yıllar,btc_Dolar,"g", marker = ".", markerfacecolor= "b")
plt.plot(yıllar,btc_Tl, "r",marker = ".", markerfacecolor= "b")
plt.ylabel("Değerler")
plt.xlabel("Yıllar")
plt.title("BTC USD - BTC TL DEĞİŞİM GRAFİĞİ")
plt.legend(["BTC DOLAR","BTC TL"])
plt.xlim(2010,2020)
plt.grid(True)

plt.show()
